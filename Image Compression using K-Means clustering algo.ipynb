# %%
import numpy as np
from sklearn import cluster, datasets
from scipy import misc
from sklearn.cluster import KMeans
import numpy as np
from skimage import io

# %%
face = misc.face()

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(face)

# %%
plt.show()

# %%
rows = face.shape[0]
cols = face.shape[1]

# %%
face = face.reshape(face.shape[0]*face.shape[1],3)

# %%
kmeans = KMeans(n_clusters = 5)
kmeans.fit(face)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[  27.06595814,   30.9811174 ,   21.48861409],
#        [ 113.96314594,  123.18195314,  103.27879788],
#        [ 196.62891602,  192.01340206,  205.50506456],
#        [  74.23540541,   84.24586787,   63.00409283],
#        [ 156.02947652,  166.38968095,  140.51951235]])

# %%
clusters = np.asarray(kmeans.cluster_centers_,dtype=np.uint8)

# %%
labels = np.asarray(kmeans.labels_,dtype=np.uint8 )

# %%
labels = labels.reshape(rows,cols);

# %%
np.save('codebook_racoon.npy',clusters)

# %%
io.imsave('compressed_racoon.png',labels);
# Out:
# /anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: compressed_racoon.png is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
image = io.imread('compressed_racoon.png')
io.imshow(image)
io.show()
# Out:
# /anaconda2/lib/python2.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
